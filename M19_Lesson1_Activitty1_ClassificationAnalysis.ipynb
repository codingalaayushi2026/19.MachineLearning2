# %% [markdown]
# <a href="https://colab.research.google.com/github/codingalaayushi2026/19.MachineLearning2/blob/main/M19_Lesson1_Activitty1_ClassificationAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer

dataset = load_breast_cancer()

# %%
sns.set_style('dark')

# %% [markdown]
# you get a darker plotting style.

# %% [markdown]
# This loads a custom style file from the internet.
#
# It changes things like
#
# Fonts,
# Colors,
# Grid style,
# Axis appearance
#
# This is only for making plots look nicer. It does not change the data.

# %%
import matplotlib as mpl
mpl.style.use(['https://gist.githubusercontent.com/BrendanMartin/01e71bb9550774e2ccff3af7574c0020/raw/6fa9681c7d0232d34c9271de9be150e584e606fe/lds_default.mplstyle'])

# %% [markdown]
# "figure.figsize": (8,6)
#
# Makes every graph
#
# Width = 8 inches
#
# Height = 6 inches

# %%
mpl.rcParams.update({"figure.figsize": (8,6), "axes.titlepad": 22.0})

# %% [markdown]
# print target names['malignant', 'benign']

# %%
print('Target variables  : ', dataset['target_names'])
# Out:
# Target variables  :  ['malignant' 'benign']

# %% [markdown]
# np.unique(dataset['target'])
# returns
#
# [0 1]
#
# because there are only two unique values.
#
# returns two arrays.
#
# Example
#
# array([0,1])
#
# array([212,357])

# %%
(unique, counts) = np.unique(dataset['target'], return_counts=True)

# %%
print('Unique values of the target variable', unique)
print('Counts of the target variable :', counts)
# Out:
# Unique values of the target variable [0 1]
# Counts of the target variable : [212 357]

# %%
sns.barplot(x=dataset['target_names'], y=counts)
plt.title('Target variable counts in dataset')
plt.show()
