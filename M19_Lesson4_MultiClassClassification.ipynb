# %% [markdown]
# <a href="https://colab.research.google.com/github/codingalaayushi2026/19.MachineLearning2/blob/main/M19_Lesson4_MultiClassClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import datasets
import numpy as np
import matplotlib.pyplot as plt

# Load dataset
iris = datasets.load_iris()

X = iris.data[:, :2]
Y = iris.target

# Create model
logreg = LogisticRegression(max_iter=200)

# Train model
logreg.fit(X, Y)

# Create mesh grid
x_min, x_max = X[:,0].min()-0.5, X[:,0].max()+0.5
y_min, y_max = X[:,1].min()-0.5, X[:,1].max()+0.5

h = 0.02

xx, yy = np.meshgrid(
    np.arange(x_min, x_max, h),
    np.arange(y_min, y_max, h)
)

# Predict
Z = logreg.predict(np.c_[xx.ravel(), yy.ravel()])

Z = Z.reshape(xx.shape)

# Plot decision boundary
plt.figure(figsize=(6,5))
plt.pcolormesh(xx, yy, Z, cmap=plt.cm.Paired, shading="auto")

# Plot training points
plt.scatter(
    X[:,0],
    X[:,1],
    c=Y,
    edgecolors='k',
    cmap=plt.cm.Paired
)

plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.show()

print("Accuracy:", logreg.score(X, Y))
# Out:
# Accuracy: 0.82
